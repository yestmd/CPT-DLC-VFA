# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import glob
import os

# %%
import pandas as pd

# %%
import numpy as np

# %%
disk_path="put the disk directory here"

# %%
path_folder=disk_path+"CPT_TOT_manuscript\\data processing\\fig\\stage 3 training\\"
file="d_stage 3 training.csv"
df_path = os.path.join(path_folder, file)
name=os.path.basename(df_path)

save_path=path_folder+ "\\mainbody_revised_plot"

df=pd.read_csv(df_path)
sns.set(font_scale = 1.5)
sns.set_style(style="ticks")
plot=sns.pointplot(x='session_order', y='value', data=df, errorbar=('ci', 68), 
                   hue='gander', hue_order=['male', 'female'], palette=['royalblue', 'coral'], capsize=.15, errwidth=1) # , color=c#legend_out=True,  #,hue='s_pc' palette=color_dict, marker='o',hue_order=order)


plt.legend(bbox_to_anchor=(1.4, 1),borderaxespad=0)
new_labels = ["1", "2", "3", "4", "5", "6", "7"]
plot.set_xticklabels(new_labels)
#plot.set_yticklabels(plt.yticks(), size=12)

plot.set(xlabel="Session")
plot.set(ylabel="d'")
plot.spines['right'].set_visible(False)
plot.spines['top'].set_visible(False)

plt.ylim(-0.2, 1.4)
#plt.xticks(rotation = 45, ha='right')
plt.savefig(save_path+'\%s.png'%(name[:-4]), dpi=800, bbox_inches="tight")
plt.close()

# %%
path_folder=disk_path+"CPT_TOT_manuscript\\data processing\\fig\\stage 3 training\\"
file="Hit_Rate_stage 3 training.csv"
df_path = os.path.join(path_folder, file)
name=os.path.basename(df_path)

save_path=path_folder+ "\\mainbody_revised_plot"

df=pd.read_csv(df_path)
sns.set(font_scale = 1.5)
sns.set_style(style="ticks")
plot=sns.pointplot(x='session_order', y='value', data=df, errorbar=('ci', 68), 
                   hue='gander', hue_order=['male', 'female'], palette=['royalblue', 'coral'], capsize=.15, errwidth=1) # , color=c#legend_out=True,  #,hue='s_pc' palette=color_dict, marker='o',hue_order=order)


plt.legend(bbox_to_anchor=(1.4, 1),borderaxespad=0)
new_labels = ["1", "2", "3", "4", "5", "6", "7"]
plot.set_xticklabels(new_labels)
plot.set(xlabel="Session")
plot.set(ylabel="HR")
plot.spines['right'].set_visible(False)
plot.spines['top'].set_visible(False)


plt.ylim(0, 0.6)
#plt.xticks(rotation = 45, ha='right')
plt.savefig(save_path+'\%s.png'%(name[:-4]), dpi=800, bbox_inches="tight")
plt.close()

# %%
path_folder=disk_path+"CPT_TOT_manuscript\\data processing\\fig\\stage 3 training\\"
file="False_Alarm_Rate_stage 3 training.csv"
df_path = os.path.join(path_folder, file)
name=os.path.basename(df_path)

save_path=path_folder+ "\\mainbody_revised_plot"

df=pd.read_csv(df_path)
sns.set(font_scale = 1.5)
sns.set_style(style="ticks")
plot=sns.pointplot(x='session_order', y='value', data=df, errorbar=('ci', 68), 
                   hue='gander', hue_order=['male', 'female'], palette=['royalblue', 'coral'], capsize=.15, errwidth=1) # , color=c#legend_out=True,  #,hue='s_pc' palette=color_dict, marker='o',hue_order=order)


plt.legend(bbox_to_anchor=(1.4, 1),borderaxespad=0)
new_labels = ["1", "2", "3", "4", "5", "6", "7"]
plot.set_xticklabels(new_labels)
plot.set(xlabel="Session")
plot.set(ylabel="FAR")
plot.spines['right'].set_visible(False)
plot.spines['top'].set_visible(False)


plt.ylim(0, )
#plt.xticks(rotation = 45, ha='right')
plt.savefig(save_path+'\%s.png'%(name[:-4]), dpi=800, bbox_inches="tight")
plt.close()

# %%
path_folder=disk_path+"CPT_TOT_manuscript\\data processing\\fig\\stage 3 training\\"
file="c_stage 3 training.csv"
df_path = os.path.join(path_folder, file)
name=os.path.basename(df_path)

save_path=path_folder+ "\\mainbody_revised_plot"

df=pd.read_csv(df_path)
sns.set(font_scale = 1.5)
sns.set_style(style="ticks")
plot=sns.pointplot(x='session_order', y='value', data=df, errorbar=('ci', 68), 
                   hue='gander', hue_order=['male', 'female'], palette=['royalblue', 'coral'], capsize=.15, errwidth=1) # , color=c#legend_out=True,  #,hue='s_pc' palette=color_dict, marker='o',hue_order=order)


plt.legend(bbox_to_anchor=(1.4, 1),borderaxespad=0)
new_labels = ["1", "2", "3", "4", "5", "6", "7"]
plot.set_xticklabels(new_labels)
plot.set(xlabel="Session")
plot.set(ylabel="c")
plot.spines['right'].set_visible(False)
plot.spines['top'].set_visible(False)


plt.ylim(0,)
#plt.xticks(rotation = 45, ha='right')
plt.savefig(save_path+'\%s.png'%(name[:-4]), dpi=800, bbox_inches="tight")
plt.close()

# %%
# revised the stage 3 supplementary fig
def filter_directories(parent_directory, strings_to_match):
    matching_directories = []
    for directory in os.listdir(parent_directory):
        if any(string in directory for string in strings_to_match):
            matching_directories.append(os.path.join(parent_directory, directory))
    return matching_directories

def path_contain_string (lst, substring):
    return [element for element in lst if substring in element]


path_folder=disk_path+"CPT_TOT_manuscript\\data processing\\fig\\stage 3 training"
strings=['Correct_Rejections', "Hits_", "Misses_", "Mistakes_", "impuls_", "si_", "ri_"]
title=["Correct rejection", "Hit", "Miss", "False alarm", "Impulsive(%)", "SI", "RI"]
df_list=filter_directories(path_folder,strings)

save_path=path_folder+ "\\sup_revised_plot"
os.makedirs(save_path, exist_ok=True)

for i, t in zip(strings, title):
    path=path_contain_string(df_list, i)
    #print(path)
    name=os.path.basename(path[0])

    df=pd.read_csv(path[0])
    sns.set(font_scale = 1.5)
    sns.set_style(style="ticks")
    plot=sns.pointplot(x='session_order', y='value', data=df, errorbar=('ci', 68), 
                       hue='gander', hue_order=['male', 'female'], palette=['royalblue', 'coral'], capsize=.15, errwidth=1) # , color=c#legend_out=True,  #,hue='s_pc' palette=color_dict, marker='o',hue_order=order)


    plt.legend(bbox_to_anchor=(1.4, 1),borderaxespad=0)
    new_labels = ["1", "2", "3", "4", "5", "6", "7"]
    plot.set_xticklabels(new_labels)
    plot.set(xlabel="Session")
    plot.set(ylabel=t)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)

    if "ri_" in name:
        plt.ylim(-0.7, 0)
    elif "si_" in name:
        plt.ylim(-0.1,0.6 )
    else:
        plt.ylim(0, )
    #plt.xticks(rotation = 45, ha='right')
    plt.savefig(save_path+'\%s.png'%(name[:-4]), dpi=800, bbox_inches="tight")
    plt.close()

# %%
# revise plot for mainbody of TOT
folder_path=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\tot_15"

file=["d_15min_bin_1_tot_15.csv", "hr_15min_bin_1_tot_15.csv", "fr_15min_bin_1_tot_15.csv", "c_15min_bin_1_tot_15.csv"]
title=["d'", "HR", "FAR", "c"]
yaxis=[0,None, 0, None, 0, 0.25, 0, None,]
num=[0, 2, 4, 6]

save_path=folder_path+ "\\mainbody_revised_plot"
os.makedirs(save_path, exist_ok=True)

for i, h, n in zip (file, title, num):
    df_path = os.path.join(folder_path, i)
    name=os.path.basename(df_path)

    df=pd.read_csv(df_path)
    sns.set(font_scale = 1.5)
    sns.set_style(style="ticks")
    plot=sns.pointplot(x='param', y='value', data=df, errorbar=('ci', 68), 
                       hue='gander', hue_order=['male', 'female'], palette=['royalblue', 'coral'], capsize=.15, errwidth=1) # , color=c#legend_out=True,  #,hue='s_pc' palette=color_dict, marker='o',hue_order=order)


    plt.legend(bbox_to_anchor=(1.4, 1),borderaxespad=0)
    new_labels = ["1", "2", "3", "4", "5", "6"]
    plot.set_xticklabels(new_labels)
    #plot.set_yticklabels(plt.yticks(), size=12)

    plot.set(xlabel="Bin")
    plot.set(ylabel=h)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)

    plt.ylim(yaxis[n], yaxis[n+1])
    #plt.xticks(rotation = 45, ha='right')
    plt.savefig(save_path+'\%s.png'%(name[:-4]), dpi=800, bbox_inches="tight")
    plt.close()

# %%
# revise plot for supplemental of TOT
def filter_directories(parent_directory, strings_to_match):
    matching_directories = []
    for directory in os.listdir(parent_directory):
        if any(string in directory for string in strings_to_match):
            matching_directories.append(os.path.join(parent_directory, directory))
    return matching_directories

def path_contain_string (lst, substring):
    return [element for element in lst if substring in element]

folder_path=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\tot_15"
df_list=glob.glob(folder_path+"\\*.csv")

strings=['Correct_Rejections', "Hits_", "Misses_", "Mistakes_", "rp_", "si_", "ri_"]

title=["Correct rejection", "Hit", "Miss", "False alarm", "Impulsive(%)", "SI", "RI"]
yaxis=[0,70, 0, 50, 0, 60, 0, None, 0, None, 0, None, 0, 0]
num=[0, 2, 4, 6, 8, 10, 12]

save_path=folder_path+ "\\sup_revised_plot"
os.makedirs(save_path, exist_ok=True)

for i, h, n in zip (strings, title, num):
    df_path=path_contain_string(df_list,i)
    name=os.path.basename(df_path[0])

    df=pd.read_csv(df_path[0])
    sns.set(font_scale = 1.5)
    sns.set_style(style="ticks")
    plot=sns.pointplot(x='param', y='value', data=df, errorbar=('ci', 68), 
                       hue='gander', hue_order=['male', 'female'], palette=['royalblue', 'coral'], capsize=.15, errwidth=1) # , color=c#legend_out=True,  #,hue='s_pc' palette=color_dict, marker='o',hue_order=order)


    plt.legend(bbox_to_anchor=(1.4, 1),borderaxespad=0)
    new_labels = ["1", "2", "3", "4", "5", "6"]
    plot.set_xticklabels(new_labels)
    #plot.set_yticklabels(plt.yticks(), size=12)

    plot.set(xlabel="Bin")
    plot.set(ylabel=h)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    if "ri_" in name:
        plt.ylim(plt.ylim()[yaxis[n]], yaxis[n+1])
    else: 
        plt.ylim(yaxis[n], yaxis[n+1])
    #plt.xticks(rotation = 45, ha='right')
    plt.savefig(save_path+'\%s.png'%(name[:-4]), dpi=800, bbox_inches="tight")
    plt.close()

# %%
# revise orientation index plot total
sns.set(font_scale = 1.5)
sns.set_style(style="ticks")

path=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\15_ori_index_LH_total\\15_ori_index_LH_total_adjust_scale"

#split male and female
df_list=[ disk_path+'\\CPT_TOT_manuscript\\data processing\\fig\\15_ori_index_LH_total\\female_total_ori_index_in_LH_15min_bin_ori_index_total_algorithm2.csv',
 disk_path+'\\CPT_TOT_manuscript\\data processing\\fig\\15_ori_index_LH_total\\male_total_ori_index_in_LH_15min_bin_ori_index_total_algorithm2.csv']

#folder="15_ori_index_LH_total_adjust_scale"

for i in df_list:
    df=pd.read_csv(i)
    if df["gander"][2]=="male":
        p='royalblue'
        #title="male_total_ori_index_in_LH_15min_bin"
    else:
        p='coral'
        #title="female_total_ori_index_in_LH_15min_bin"
    plot=sns.pointplot(data=df, x="min_15bin", y="ori_index_total_algorithm2", capsize=.15, errorbar=('ci', 68), color=p, errwidth=1)
    #plt.setp(plot.collections, sizes=[70])
    plot.set(xlabel="Bin")
    plot.set(ylabel="Total orientation index")
    new_labels = ["1", "2", "3", "4", "5", "6"]
    plot.set_xticklabels(new_labels)
    plt.ylim(0.20, 1.20)
    #plt.title(title)
    #plt.xticks(rotation = 15, ha='right')
    plt.legend(bbox_to_anchor=(1.30, 1),borderaxespad=0)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.savefig(path+"\%s_corrected_changg_scale.png"%(df["gander"][2]), dpi=800, bbox_inches="tight")
    plt.close()
    
#combine male and female    
df_list=['disk_path+\\CPT_TOT_manuscript\\data processing\\fig\\15_ori_index_LH_total\\male_vs_female_total_ori_index_in_LH_15min_bin_corrected.csv']
    #save_path=path+folder
    #if os.path.isdir(save_path ) == False:
        #os.mkdir(save_path)
plot=sns.pointplot(data=df, x="min_15bin", y="ori_index_total_algorithm2",hue='gander', hue_order=['male', 'female'], palette=['royalblue', 'coral'], capsize=.15, errwidth=1, errorbar=('ci', 68)) #linestyles=['-', '-.', ':', '--'],
#plt.setp(plot.collections, sizes=[70])
plot.set(xlabel="")
plot.set(ylabel="Total orientation index")
title='male_vs_female_total_ori_index_in_LH'
plt.title(title)
new_labels = ["1", "2", "3", "4", "5", "6"]
plot.set_xticklabels(new_labels)
#plt.xticks(rotation = 15, ha='right')
plt.ylim(0.2, 1.20)
#     h = plt.gca().get_lines()
#     lg = plt.legend(handles=h, labels=['oriented', 'blind'], loc='best')
plt.legend(bbox_to_anchor=(1.30, 1),borderaxespad=0)
plot.spines['right'].set_visible(False)
plot.spines['top'].set_visible(False)
save_path=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\15_ori_index_LH_total"    
plt.savefig(save_path+"\\%s_corrected_scale.png"%(title), dpi=800, bbox_inches="tight")
plt.close()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#revise the plot of event orientation index
def filter_directories(parent_directory, strings_to_match):
    matching_directories = []
    for directory in os.listdir(parent_directory):
        if any(string in directory for string in strings_to_match):
            matching_directories.append(os.path.join(parent_directory, directory))
    return matching_directories

def path_contain_string (lst, substring):
    return [element for element in lst if substring in element]

path=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\15_ori_index_LH\\"
df_list=[disk_path+'\\CPT_TOT_manuscript\\data processing\\fig\\15_ori_index_LH\\female_ori_index_before_event_15min_bin_corrected.csv',
 disk_path+'\\CPT_TOT_manuscript\\data processing\\fig\\15_ori_index_LH\\male_ori_index_before_event_15min_bin_corrected.csv']
sns.set(font_scale = 1.5)
sns.set_style(style="ticks")

folder="15_ori_index_LH_adjust_scale"

for i in df_list:
    df=pd.read_csv(i)
    if df["gander"][2]=="male":
        p='royalblue'
        x='male'
    else:
        p='coral'
        x='female'
        
    #title="%s_ori_index_in_LH_15min_bin"%(x)   
    plot=sns.pointplot(data=df, x="min_15bin", y="ori_index_event", hue="event_type",  hue_order=["hit", "miss", "mistake", "corr_reject"], palette=[p, p, p, p], 
                        markers=["o", "x","D", "*"], capsize=.15, errwidth=1, errorbar=('ci', 68), linestyles=['-', '-.', ':', '--']) #,
    plt.setp(plot.collections, sizes=[70])
    plot.set(xlabel="Bin")
    plot.set(ylabel="Event orientation index")
    plt.ylim(0.20, 1.20 )
    #plt.title(title)
    #plt.xticks(rotation = 15, ha='right')
    new_labels = ["1", "2", "3", "4", "5", "6"]
    plot.set_xticklabels(new_labels)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.legend(bbox_to_anchor=(1.30, 1),borderaxespad=0)

    save_path=path+folder
    if os.path.isdir(save_path ) == False:
        os.mkdir(save_path)
        
    plt.savefig(save_path+"\%s_event_orientation_index.png"%(x), dpi=800, bbox_inches="tight")
    plt.close()
# Out:
# C:\Users\ye.li\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.3137254901960784)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# C:\Users\ye.li\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((0.2549019607843137, 0.4117647058823529, 0.8823529411764706)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
# revise the main body plot of amph
path_folder=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\amph_tot_15"
df_list=glob.glob(path_folder+"\\*.csv")

keyword=["_d_15bin", "_hit_rate_15bin", "_false_alarm_rate_15bin", "_c_15bin"]
title=["d'", "HR", "FAR", "c"]
save_folder=path_folder+"\\publication"
os.makedirs(save_folder, exist_ok=True)

yaxis=[0,None, 0, None, 0, None, 0, None,]
num=[0, 2, 4, 6]


for i, h, n in zip(keyword, title, num):    
    df_path=path_contain_string(df_list,i)

    for j in df_path:        
        name=os.path.basename(j)
        df=pd.read_csv(j)

        if "female_" in name:
            plot=sns.pointplot(x='param', y='value', hue='dosage', data=df, errorbar=('ci', 68),
                            palette=["peachpuff", "hotpink",  "coral", "maroon"], 
                           hue_order=["AMPH-vehicle", "AMPH-0.3mpk", "AMPH-0.6mpk","AMPH-1mpk"],
                            linestyles=['-', ':', '-.', '--'], capsize=.15, errwidth=1)
        else:

            plot=sns.pointplot(x='param', y='value', hue='dosage', data=df, errorbar=('ci', 68),
                                    palette=["powderblue", "deepskyblue",  "royalblue", "midnightblue"], 
                                   hue_order=["AMPH-vehicle", "AMPH-0.3mpk", "AMPH-0.6mpk","AMPH-1mpk"],
                                    linestyles=['-', ':', '-.', '--'], capsize=.15, errwidth=1)

        plt.legend(bbox_to_anchor=(1.5, 1.1),borderaxespad=0)
        new_labels = ["1", "2", "3", "4", "5", "6"]
        plot.set_xticklabels(new_labels)
        plot.set(xlabel="Bin")
        plot.set(ylabel=h)
        plt.ylim(yaxis[n], yaxis[n+1])
        plot.spines['right'].set_visible(False)
        plot.spines['top'].set_visible(False)
        plt.savefig(save_folder+"\\%s.png"%(name[:-4]), dpi=800, bbox_inches="tight")
        plt.close()

# %%
# revise the sup plot of amph
path_folder=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\amph_tot_15"
df_list=glob.glob(path_folder+"\\*.csv")

keyword=['_correj_15bin', "_hit_15bin", "_miss_15bin", "_false_15bin", "_impuls_15bin", "_si_15bin", "_ri_15bin"]
title=["Correct rejection", "Hit", "Miss", "False alarm", "Impulsive(%)", "SI", "RI"]

save_folder=path_folder+"\\publication"
os.makedirs(save_folder, exist_ok=True)

yaxis=[0,70, 0, 50, 0, 60, 0, None, 0, None, 0, None, 0, 0]
num=[0, 2, 4, 6, 8, 10, 12]



for i, h, n in zip(keyword, title, num):    
    df_path=path_contain_string(df_list,i)

    for j in df_path:        
        name=os.path.basename(j)
        df=pd.read_csv(j)

        if "female_" in name:
            plot=sns.pointplot(x='param', y='value', hue='dosage', data=df, errorbar=('ci', 68),
                            palette=["peachpuff", "hotpink",  "coral", "maroon"], 
                           hue_order=["AMPH-vehicle", "AMPH-0.3mpk", "AMPH-0.6mpk","AMPH-1mpk"],
                            linestyles=['-', ':', '-.', '--'], capsize=.15, errwidth=1)
        else:

            plot=sns.pointplot(x='param', y='value', hue='dosage', data=df, errorbar=('ci', 68),
                                    palette=["powderblue", "deepskyblue",  "royalblue", "midnightblue"], 
                                   hue_order=["AMPH-vehicle", "AMPH-0.3mpk", "AMPH-0.6mpk","AMPH-1mpk"],
                                    linestyles=['-', ':', '-.', '--'], capsize=.15, errwidth=1)

        plt.legend(bbox_to_anchor=(1.5, 1.1),borderaxespad=0)
        new_labels = ["1", "2", "3", "4", "5", "6"]
        plot.set_xticklabels(new_labels)
        plot.set(xlabel="Bin")
        plot.set(ylabel=h)
        if "_ri_" in name:
            plt.ylim(plt.ylim()[yaxis[n]], yaxis[n+1])
        else: 
            plt.ylim(yaxis[n], yaxis[n+1])
        
        plot.spines['right'].set_visible(False)
        plot.spines['top'].set_visible(False)
        plt.savefig(save_folder+"\\%s.png"%(name[:-4]), dpi=800, bbox_inches="tight")
        plt.close()

# %%
# total orientation index amph injection

path=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\15_amph_ori_index_LH_V2_total\\"
df_list=glob.glob(path+"*.csv")

folder="for_publication"

for i in df_list:
    df=pd.read_csv(i)
    if df["gander"][2]=="male":
        plot=sns.pointplot(data=df, x="min_15bin", y="ori_index_total", hue="dosage",  
                       hue_order=["AMPH-vehicle", "AMPH-0.3mpk", "AMPH-0.6mpk","AMPH-1mpk"], dodge=True,
                       palette=["powderblue", "deepskyblue",  "royalblue", "midnightblue"], 
                           linestyles=['-', ':', '-.', '--'],
                           capsize=.15, errwidth=1, errorbar=('ci', 68))
      
    else:
        plot=sns.pointplot(data=df, x="min_15bin", y="ori_index_total", hue="dosage",  
                       hue_order=["AMPH-vehicle", "AMPH-0.3mpk", "AMPH-0.6mpk","AMPH-1mpk"], dodge=True,
                       palette=["peachpuff", "hotpink",  "coral", "maroon"], linestyles=['-', ':', '-.', '--'],
                           capsize=.15, errwidth=1, errorbar=('ci', 68))       


    plot.set(xlabel="")
    plot.set(ylabel="Total orientation index")
    new_labels = ["1", "2", "3", "4", "5", "6"]
    plot.set_xticklabels(new_labels)
    plot.set(xlabel="Bin")
    #plt.ylim(0.80, 1.0 )
    plot.yaxis.set_ticks(np.arange(0.40, 1.2, 0.1))
    #plt.title(title)
    #plt.xticks(rotation = 15, ha='right')
#     h = plt.gca().get_lines()
#     lg = plt.legend(handles=h, labels=['oriented', 'blind'], loc='best')
    plt.legend(bbox_to_anchor=(1.05, 1),borderaxespad=0)
    save_path=path+folder
    if os.path.isdir(save_path ) == False:
        os.mkdir(save_path) 
    #df.to_csv(save_path+"\\"+title+".csv")
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.savefig(save_path+"\\%s_total_ori_index.png"%(df["gander"][2]), dpi=800, bbox_inches="tight")
    plt.close()

# %%
#individual event orientation index after amph

path=disk_path+"\\CPT_TOT_manuscript\\data processing\\fig\\15_amph_ori_index_LH_V2\\"
df_list=glob.glob(path+"*.csv")

folder="for_publication_event"

for i in df_list:
    df=pd.read_csv(i)
    
    if df["gander"][2]=="male":
        plot=sns.pointplot(data=df, x='min_15bin', y='ori_index', hue='dosage', 
                        hue_order=["AMPH-vehicle", "AMPH-0.3mpk", "AMPH-0.6mpk","AMPH-1mpk"], dodge=True,
                       palette=["powderblue", "deepskyblue",  "royalblue", "midnightblue"], 
                           linestyles=['-', ':', '-.', '--'], capsize=.15, errwidth=1, errorbar=('ci', 68))
    else:
        plot=sns.pointplot(data=df, x="min_15bin", y="ori_index", hue="dosage",  
                       hue_order=["AMPH-vehicle", "AMPH-0.3mpk", "AMPH-0.6mpk","AMPH-1mpk"], dodge=True,
                       palette=["peachpuff", "hotpink",  "coral", "maroon"], linestyles=['-', ':', '-.', '--'],
                           capsize=.15, errwidth=1, errorbar=('ci', 68))        
    
                      
    plot.set(xlabel="")
    plot.set(ylabel="Event orientation index")
    new_labels = ["1", "2", "3", "4", "5", "6"]
    plot.set_xticklabels(new_labels)
    plot.set(xlabel="Bin")
    plot.yaxis.set_ticks(np.arange(0.40, 1.2, 0.1))
    title=df["gander"][2]+"_orientation_index_of_"+df["event_type"][2]+"_in_LH"
    print(title)
    #plt.title(title)
    #plt.xticks(rotation = 45, ha='right')
    plt.legend(bbox_to_anchor=(1.05, 1),borderaxespad=0)
    
    save_path=path+folder
    if os.path.isdir(save_path) == False:
        os.mkdir(save_path)
        
    #df.to_csv(save_path+"\\"+title+".csv")
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.savefig(save_path+ "\\%s.png"%(title), dpi=800, bbox_inches="tight")
    plt.close()
# Out:
# female_orientation_index_of_corr_reject_in_LH
# female_orientation_index_of_hit_in_LH
# female_orientation_index_of_miss_in_LH
# female_orientation_index_of_mistake_in_LH
# male_orientation_index_of_corr_reject_in_LH
# male_orientation_index_of_hit_in_LH
# male_orientation_index_of_miss_in_LH
# male_orientation_index_of_mistake_in_LH
